# %%
Лабораторная работа 1
Выполнил студент БПИ2301 Синюк Максим Павлович
Задание 1

# %%
print("Hello");
# Out:
# Hello

# %%
#Задание 2

# %%
import random
import time
import heapq


def generate_matrix(m=50, n=50, min_limit=-250, max_limit=1005):

    return [[random.randint(min_limit, max_limit) for _ in range(n)] for _ in range(m)]

matrix = generate_matrix()
for row in matrix:
    print(row)
# Out:
# [723, 876, 110, -51, 276, 737, 547, 784, 524, 389, 180, 660, 804, 959, 316, 981, -139, -188, 160, 256, 665, 513, 542, 227, -86, -183, 192, 399, 317, -92, 363, 730, 111, 766, 220, 967, 293, 76, 429, 272, 892, 969, 625, 808, 751, 602, 555, -141, 1000, 970]
# [0, -63, -90, 302, 805, 1000, -228, 679, 187, 154, 244, 891, 920, 699, -241, 502, 425, 795, 497, 722, 13, 97, 198, -208, 833, 722, -40, -222, 281, 217, 922, 607, 775, 32, 82, 752, -53, -95, -22, -30, 749, 12, 337, 22, 352, 555, -113, 141, -199, -214]
# [567, 712, 929, -149, -199, 582, 650, 153, 391, 716, 339, 448, 297, 766, 748, 57, 295, 700, 860, 411, 286, -96, 889, 401, 638, 357, 660, -179, -57, 689, -122, 725, 293, -147, 370, -99, 522, 471, -47, 172, 342, 462, 997, 546, 90, -33, -194, -142, 464, 821]
# ...

# %%
 #Задание 3

# %%
def selection_sort(arr):
    for i in range(len(arr)):
        min_idx = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key


def exchange_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(i + 1, n):
            if arr[i] > arr[j]:
                arr[i], arr[j] = arr[j], arr[i]


def shell_sort(arr):
    gap = len(arr) // 2
    while gap > 0:
        for i in range(gap, len(arr)):
            temp = arr[i]
            j = i
            while j >= gap and arr[j - gap] > temp:
                arr[j] = arr[j - gap]
                j -= gap
            arr[j] = temp
        gap //= 2

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

def heap_sort(arr):
    heapq.heapify(arr)
    return [heapq.heappop(arr) for _ in range(len(arr))]

def tournament_sort(arr):
    sorted_arr = []
    while arr:
        min_val = min(arr)
        sorted_arr.append(min_val)
        arr.remove(min_val)
    return sorted_arr

def pyramidal_sort(arr):
    n = len(arr)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
    
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)

def heapify(arr, n, i):
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2
    
    if left < n and arr[left] > arr[largest]:
        largest = left
    
    if right < n and arr[right] > arr[largest]:
        largest = right
    
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)

def measure_time(sort_function, matrix):
    start_time = time.time()
    sorted_matrix = [sort_function(row[:]) for row in matrix]
    end_time = time.time()
    return end_time - start_time


def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
def exchange_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(i + 1, n):
            if arr[i] > arr[j]:
                arr[i], arr[j] = arr[j], arr[i]
                
matrix = generate_matrix()
sort_methods = {
    "Selection Sort": selection_sort,
    "Insertion Sort": insertion_sort,
    "Exchange Sort": exchange_sort,
    "Shell Sort": shell_sort,
    "Quick Sort": quick_sort,
    "Heap Sort": heap_sort,
    "Tournament Sort": tournament_sort,
    "Pyramidal Sort": pyramidal_sort,
    "Bubble Sort": bubble_sort,
    "Sorted": sorted
}

results = {name: measure_time(func, matrix) for name, func in sort_methods.items()}
for method, time_taken in results.items():
    print(f"{method}: {time_taken:.5f} seconds , diff {(time_taken - results['Sorted']):.5f} seconds")
# Out:
# Selection Sort: 0.00300 seconds , diff 0.00149 seconds
# Insertion Sort: 0.00201 seconds , diff 0.00050 seconds
# Exchange Sort: 0.00495 seconds , diff 0.00344 seconds
# Shell Sort: 0.00293 seconds , diff 0.00142 seconds
# Quick Sort: 0.00602 seconds , diff 0.00451 seconds
# Heap Sort: 0.00000 seconds , diff -0.00151 seconds
# Tournament Sort: 0.00315 seconds , diff 0.00164 seconds
# Pyramidal Sort: 0.00285 seconds , diff 0.00134 seconds
# Bubble Sort: 0.00598 seconds , diff 0.00446 seconds
# Sorted: 0.00151 seconds , diff 0.00000 seconds
